# %%
# Mount ADLS Gen2
# Required each time the cluster is restarted which should be only on the first notebook as they run in order

tiers = ["bronze", "silver", "gold"]
adls_paths = {tier: f"abfss://{tier}@eqstoreacc.dfs.core.windows.net/" for tier in tiers}

# Accessing paths
bronze_adls = adls_paths["bronze"]
silver_adls = adls_paths["silver"]
gold_adls = adls_paths["gold"] 

dbutils.fs.ls(bronze_adls)
dbutils.fs.ls(silver_adls)
dbutils.fs.ls(gold_adls)
# Out:
# []

# %%
import requests
import json
from datetime import date, timedelta

# %%
# Get base parameters
dbutils.widgets.text("start_date", "")
dbutils.widgets.text("end_date", "")

start_date = dbutils.widgets.get("start_date")
end_date = dbutils.widgets.get("end_date")

# %%
# Construct the API URL with start and end dates provided by Data Factory, formatted for geojson output.
url = f"https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson&starttime={start_date}&endtime={end_date}"

try:
    # Make the GET request to fetch data
    response = requests.get(url)

    # Check if the request was successful
    response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)
    data = response.json().get('features', [])

    if not data:
        print("No data returned for the specified date range.")
    else:
        # Specify the ADLS path
        file_path = f"{bronze_adls}/{start_date}_earthquake_data.json"

        # Save the JSON data
        json_data = json.dumps(data, indent=4)
        dbutils.fs.put(file_path, json_data, overwrite=True)
        print(f"Data successfully saved to {file_path}")
except requests.exceptions.RequestException as e:
    print(f"Error fetching data from API: {e}")
# Out:
# Wrote 358358 bytes.
# Data successfully saved to abfss://bronze@eqstoreacc.dfs.core.windows.net//2025-08-04_earthquake_data.json

# %%
data
# Out:
# [{'type': 'Feature',
#   'properties': {'mag': 1.36,
#    'place': '8 km WNW of Cobb, CA',
#    'time': 1754351979090,
#    'updated': 1754352076665,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219247',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219247&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 28,
#    'net': 'nc',
#    'code': '75219247',
#    'ids': ',nc75219247,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 24,
#    'dmin': 0.01624,
#    'rms': 0.02,
#    'gap': 52,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 8 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.810836791992, 38.8411674499512, 1.96000003814697]},
#   'id': 'nc75219247'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.79,
#    'place': '8 km WNW of Cobb, CA',
#    'time': 1754351835690,
#    'updated': 1754351931732,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219242',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219242&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'nc',
#    'code': '75219242',
#    'ids': ',nc75219242,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.01202,
#    'rms': 0.03,
#    'gap': 109,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 8 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.816497802734, 38.8343315124512, 1.61000001430511]},
#   'id': 'nc75219242'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.53,
#    'place': '5 km NW of Boron, CA',
#    'time': 1754351082380,
#    'updated': 1754351304867,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41253104',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41253104&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 36,
#    'net': 'ci',
#    'code': '41253104',
#    'ids': ',ci41253104,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 28,
#    'dmin': 0.09531,
#    'rms': 0.18,
#    'gap': 64,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 5 km NW of Boron, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.6878333, 35.0296667, 0.49]},
#   'id': 'ci41253104'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.6,
#    'place': '75 km NW of China, Japan',
#    'time': 1754350757732,
#    'updated': 1754369003040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy4f',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy4f&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 326,
#    'net': 'us',
#    'code': '6000qy4f',
#    'ids': ',us6000qy4f,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 37,
#    'dmin': 0.994,
#    'rms': 0.32,
#    'gap': 126,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.6 - 75 km NW of China, Japan'},
#   'geometry': {'type': 'Point', 'coordinates': [128.0263, 27.8091, 10]},
#   'id': 'us6000qy4f'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.3,
#    'place': '5 km E of Assaria, Kansas',
#    'time': 1754349658936,
#    'updated': 1754369129734,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy4b',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy4b&format=geojson',
#    'felt': 21,
#    'cdi': 3.4,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 175,
#    'net': 'us',
#    'code': '6000qy4b',
#    'ids': ',us6000qy4b,',
#    'sources': ',us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 40,
#    'dmin': 0.711,
#    'rms': 0.47,
#    'gap': 75,
#    'magType': 'mb_lg',
#    'type': 'earthquake',
#    'title': 'M 3.3 - 5 km E of Assaria, Kansas'},
#   'geometry': {'type': 'Point', 'coordinates': [-97.538, 38.6742, 9.896]},
#   'id': 'us6000qy4b'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.23,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1754349524760,
#    'updated': 1754383506119,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219237',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219237&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '75219237',
#    'ids': ',nc75219237,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 12,
#    'dmin': 0.01191,
#    'rms': 0.02,
#    'gap': 57,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.2 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.822166666667, 38.8306666666667, 1.9]},
#   'id': 'nc75219237'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.69,
#    'place': '11 km ENE of Ocotillo Wells, CA',
#    'time': 1754349321750,
#    'updated': 1754349530668,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41253080',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41253080&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'ci',
#    'code': '41253080',
#    'ids': ',ci41253080,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 34,
#    'dmin': 0.04995,
#    'rms': 0.19,
#    'gap': 57,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 11 km ENE of Ocotillo Wells, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.032, 33.1941667, 5.57]},
#   'id': 'ci41253080'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.42,
#    'place': '79 km NNE of Luquillo, Puerto Rico',
#    'time': 1754349246080,
#    'updated': 1754386349356,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71491533',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71491533&format=geojson',
#    'felt': 1,
#    'cdi': 2.7,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 180,
#    'net': 'pr',
#    'code': '71491533',
#    'ids': ',pr71491533,us6000qy4a,',
#    'sources': ',pr,us,',
#    'types': ',dyfi,origin,phase-data,',
#    'nst': 20,
#    'dmin': 0.7864,
#    'rms': 0.24,
#    'gap': 237,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.4 - 79 km NNE of Luquillo, Puerto Rico'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-65.3968333333333, 19.0225, 49]},
#   'id': 'pr71491533'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.6,
#    'place': '69 km WSW of Corinto, Nicaragua',
#    'time': 1754348809153,
#    'updated': 1754366350040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy49',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy49&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 326,
#    'net': 'us',
#    'code': '6000qy49',
#    'ids': ',us6000qy49,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 190,
#    'dmin': 1.435,
#    'rms': 0.73,
#    'gap': 138,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.6 - 69 km WSW of Corinto, Nicaragua'},
#   'geometry': {'type': 'Point', 'coordinates': [-87.7211, 12.1514, 35]},
#   'id': 'us6000qy49'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '49 km SSE of Denali National Park, Alaska',
#    'time': 1754348515312,
#    'updated': 1754348620185,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xls9kb',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xls9kb&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0259xls9kb',
#    'ids': ',ak0259xls9kb,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.79,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 49 km SSE of Denali National Park, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-151.3279, 63.1324, 0]},
#   'id': 'ak0259xls9kb'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.85,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1754348426090,
#    'updated': 1754348521032,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219232',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219232&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'nc',
#    'code': '75219232',
#    'ids': ',nc75219232,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.0112,
#    'rms': 0.01,
#    'gap': 128,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.821502685547, 38.8301658630371, 1.4099999666214]},
#   'id': 'nc75219232'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.29,
#    'place': '10 km NW of Anza, CA',
#    'time': 1754347532470,
#    'updated': 1754347786327,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41253072',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41253072&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ci',
#    'code': '41253072',
#    'ids': ',ci41253072,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 53,
#    'dmin': 0.06071,
#    'rms': 0.19,
#    'gap': 25,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 10 km NW of Anza, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.7441667, 33.626, 16.15]},
#   'id': 'ci41253072'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.69,
#    'place': '12 km ENE of Borrego Springs, CA',
#    'time': 1754347503470,
#    'updated': 1754347726463,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41253064',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41253064&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 44,
#    'net': 'ci',
#    'code': '41253064',
#    'ids': ',ci41253064,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 9,
#    'dmin': 0.2226,
#    'rms': 0.25,
#    'gap': 130,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.7 - 12 km ENE of Borrego Springs, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.2555, 33.2861667, 8.82]},
#   'id': 'ci41253064'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.51,
#    'place': '8 km E of Alum Rock, CA',
#    'time': 1754346249330,
#    'updated': 1754346807959,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219217',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219217&format=geojson',
#    'felt': 1,
#    'cdi': 2,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'nc',
#    'code': '75219217',
#    'ids': ',nc75219217,',
#    'sources': ',nc,',
#    'types': ',dyfi,nearby-cities,origin,phase-data,',
#    'nst': 18,
#    'dmin': 0.08371,
#    'rms': 0.03,
#    'gap': 117,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 8 km E of Alum Rock, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.736335754395, 37.3838348388672, 6.8899998664856]},
#   'id': 'nc75219217'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.6,
#    'place': '143 km ESE of Petropavlovsk-Kamchatsky, Russia',
#    'time': 1754345473125,
#    'updated': 1754364280040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy48',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy48&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 326,
#    'net': 'us',
#    'code': '6000qy48',
#    'ids': ',us6000qy48,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 43,
#    'dmin': 1.27,
#    'rms': 0.69,
#    'gap': 201,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.6 - 143 km ESE of Petropavlovsk-Kamchatsky, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [160.7011, 52.7618, 35]},
#   'id': 'us6000qy48'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.79,
#    'place': '7 km SSW of Mojave, CA',
#    'time': 1754345189030,
#    'updated': 1754345640913,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41253008',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41253008&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 49,
#    'net': 'ci',
#    'code': '41253008',
#    'ids': ',ci41253008,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 23,
#    'dmin': 0.1234,
#    'rms': 0.23,
#    'gap': 53,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 7 km SSW of Mojave, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-118.1913333, 34.993, 0.15]},
#   'id': 'ci41253008'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.48,
#    'place': '13 km W of Toms Place, CA',
#    'time': 1754345160940,
#    'updated': 1754345255723,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219212',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219212&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 34,
#    'net': 'nc',
#    'code': '75219212',
#    'ids': ',nc75219212,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 14,
#    'dmin': 0.04981,
#    'rms': 0.03,
#    'gap': 136,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 13 km W of Toms Place, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.826835632324, 37.5401649475098, 3.44000005722046]},
#   'id': 'nc75219212'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.57,
#    'place': '13 km W of Toms Place, CA',
#    'time': 1754345110200,
#    'updated': 1754346439368,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219207',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219207&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 102,
#    'net': 'nc',
#    'code': '75219207',
#    'ids': ',nc75219207,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 24,
#    'dmin': 0.04778,
#    'rms': 0.05,
#    'gap': 95,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.6 - 13 km W of Toms Place, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-118.828163146973, 37.5421676635742, 3.63000011444092]},
#   'id': 'nc75219207'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.9,
#    'place': '186 km SSE of Vilyuchinsk, Russia',
#    'time': 1754344785444,
#    'updated': 1754358473040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy42',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy42&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 369,
#    'net': 'us',
#    'code': '6000qy42',
#    'ids': ',us6000qy42,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 64,
#    'dmin': 1.694,
#    'rms': 0.83,
#    'gap': 112,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 4.9 - 186 km SSE of Vilyuchinsk, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [159.7555, 51.4745, 10]},
#   'id': 'us6000qy42'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.45,
#    'place': '10 km S of Morton, Washington',
#    'time': 1754344191060,
#    'updated': 1754367614690,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62166016',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62166016&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 32,
#    'net': 'uw',
#    'code': '62166016',
#    'ids': ',uw62166016,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 39,
#    'dmin': 0.1095,
#    'rms': 0.08,
#    'gap': 80,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 10 km S of Morton, Washington'},
#   'geometry': {'type': 'Point', 'coordinates': [-122.2975, 46.463, 15.17]},
#   'id': 'uw62166016'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '62 km SSE of Cantwell, Alaska',
#    'time': 1754344069993,
#    'updated': 1754344201380,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xkv8vr',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xkv8vr&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0259xkv8vr',
#    'ids': ',ak0259xkv8vr,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.37,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 62 km SSE of Cantwell, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-148.3187, 62.9095, 14.9]},
#   'id': 'ak0259xkv8vr'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.9,
#    'place': '14 km ENE of Ridgecrest, CA',
#    'time': 1754343634140,
#    'updated': 1754343835788,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252976',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252976&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 12,
#    'net': 'ci',
#    'code': '41252976',
#    'ids': ',ci41252976,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 25,
#    'dmin': 0.09044,
#    'rms': 0.21,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 14 km ENE of Ridgecrest, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.534, 35.6758333, 4.53]},
#   'id': 'ci41252976'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.91,
#    'place': '4 km SSE of Home Gardens, CA',
#    'time': 1754342060230,
#    'updated': 1754342726570,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252952',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252952&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'ci',
#    'code': '41252952',
#    'ids': ',ci41252952,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 75,
#    'dmin': 0.04921,
#    'rms': 0.22,
#    'gap': 31,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 4 km SSE of Home Gardens, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.4941667, 33.8448333, 2.49]},
#   'id': 'ci41252952'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '16 km ESE of Point Possession, Alaska',
#    'time': 1754342026151,
#    'updated': 1754342150303,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xkny8n',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xkny8n&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0259xkny8n',
#    'ids': ',ak0259xkny8n,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.6,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 16 km ESE of Point Possession, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-150.439, 60.8422, 33.1]},
#   'id': 'ak0259xkny8n'},
#  {'type': 'Feature',
#   'properties': {'mag': 5,
#    'place': '140 km ESE of Ozernovskiy, Russia',
#    'time': 1754341580428,
#    'updated': 1754356705040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy3s',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy3s&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 385,
#    'net': 'us',
#    'code': '6000qy3s',
#    'ids': ',usauto6000qy3s,us6000qy3s,',
#    'sources': ',usauto,us,',
#    'types': ',internal-moment-tensor,origin,phase-data,',
#    'nst': 58,
#    'dmin': 2.079,
#    'rms': 0.55,
#    'gap': 98,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.0 - 140 km ESE of Ozernovskiy, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [158.3155, 50.9583, 35]},
#   'id': 'us6000qy3s'},
#  {'type': 'Feature',
#   'properties': {'mag': 1,
#    'place': '12 km W of Stanton, Texas',
#    'time': 1754340502150,
#    'updated': 1754354676028,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025pggmzk',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025pggmzk&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 15,
#    'net': 'tx',
#    'code': '2025pggmzk',
#    'ids': ',tx2025pggmzk,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 33,
#    'dmin': 0.1,
#    'rms': 0.1,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 12 km W of Stanton, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.918, 32.11, 8.96]},
#   'id': 'tx2025pggmzk'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.96,
#    'place': '3 km ESE of Lake Henshaw, CA',
#    'time': 1754340360120,
#    'updated': 1754340608020,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252928',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252928&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'ci',
#    'code': '41252928',
#    'ids': ',ci41252928,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 37,
#    'dmin': 0.02023,
#    'rms': 0.17,
#    'gap': 33,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 3 km ESE of Lake Henshaw, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.7368333, 33.2275, 11.45]},
#   'id': 'ci41252928'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '58 km E of Port Alsworth, Alaska',
#    'time': 1754340028016,
#    'updated': 1754340099648,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xk89kh',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xk89kh&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '0259xk89kh',
#    'ids': ',ak0259xk89kh,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.16,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 58 km E of Port Alsworth, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-153.263, 60.1709, 102]},
#   'id': 'ak0259xk89kh'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '57 km SW of Harding-Birch Lakes, Alaska',
#    'time': 1754339997170,
#    'updated': 1754340105317,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xk843p',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xk843p&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0259xk843p',
#    'ids': ',ak0259xk843p,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.42,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 57 km SW of Harding-Birch Lakes, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-147.3586, 63.9729, 9.8]},
#   'id': 'ak0259xk843p'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.97,
#    'place': '6 km W of San Pasqual, CA',
#    'time': 1754339650070,
#    'updated': 1754339915937,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252920',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252920&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 60,
#    'net': 'ci',
#    'code': '41252920',
#    'ids': ',ci41252920,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 9,
#    'dmin': 0.3543,
#    'rms': 0.21,
#    'gap': 181,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 2.0 - 6 km W of San Pasqual, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.0195, 33.0881667, 9.76]},
#   'id': 'ci41252920'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.21,
#    'place': '10 km SE of Winchester, CA',
#    'time': 1754337882800,
#    'updated': 1754338107108,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252888',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252888&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '41252888',
#    'ids': ',ci41252888,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 15,
#    'dmin': 0.005179,
#    'rms': 0.07,
#    'gap': 120,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 10 km SE of Winchester, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.0121667, 33.6453333, 12.41]},
#   'id': 'ci41252888'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.15,
#    'place': '9 km SE of Winchester, CA',
#    'time': 1754337882780,
#    'updated': 1754338008285,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252896',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252896&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 20,
#    'net': 'ci',
#    'code': '41252896',
#    'ids': ',ci41252896,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 25,
#    'dmin': 0.002391,
#    'rms': 0.17,
#    'gap': 55,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 9 km SE of Winchester, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.0123367, 33.6500015, 12.46]},
#   'id': 'ci41252896'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '55 km NNE of Chase, Alaska',
#    'time': 1754336825872,
#    'updated': 1754336950927,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xjoa9n',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xjoa9n&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0259xjoa9n',
#    'ids': ',ak0259xjoa9n,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.64,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 55 km NNE of Chase, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-149.6997, 62.9139, 52.6]},
#   'id': 'ak0259xjoa9n'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.04,
#    'place': '10 km SE of Winchester, CA',
#    'time': 1754336639380,
#    'updated': 1754336862592,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252872',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252872&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'ci',
#    'code': '41252872',
#    'ids': ',ci41252872,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 37,
#    'dmin': 0.007345,
#    'rms': 0.18,
#    'gap': 71,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 10 km SE of Winchester, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.0121667, 33.643, 12.57]},
#   'id': 'ci41252872'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.16,
#    'place': '0 km SW of Murrieta, CA',
#    'time': 1754336531680,
#    'updated': 1754336800183,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252864',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252864&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 21,
#    'net': 'ci',
#    'code': '41252864',
#    'ids': ',ci41252864,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 46,
#    'dmin': 0.05084,
#    'rms': 0.23,
#    'gap': 44,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 0 km SW of Murrieta, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.2165, 33.5521667, 10.96]},
#   'id': 'ci41252864'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.1,
#    'place': '24 km NNW of Karluk, Alaska',
#    'time': 1754336339684,
#    'updated': 1754336446820,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xjmgz4',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xjmgz4&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 19,
#    'net': 'ak',
#    'code': '0259xjmgz4',
#    'ids': ',ak0259xjmgz4,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.12,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 24 km NNW of Karluk, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-154.6127, 57.7705, 46.1]},
#   'id': 'ak0259xjmgz4'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.8,
#    'place': '14 km E of Stanton, Texas',
#    'time': 1754336150433,
#    'updated': 1754344658953,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/tx2025pgecmf',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=tx2025pgecmf&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 50,
#    'net': 'tx',
#    'code': '2025pgecmf',
#    'ids': ',tx2025pgecmf,',
#    'sources': ',tx,',
#    'types': ',origin,phase-data,',
#    'nst': 38,
#    'dmin': 0,
#    'rms': 0.1,
#    'gap': 43,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.8 - 14 km E of Stanton, Texas'},
#   'geometry': {'type': 'Point', 'coordinates': [-101.637, 32.138, 6.4209]},
#   'id': 'tx2025pgecmf'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.76,
#    'place': '6 km SSE of Lake Henshaw, CA',
#    'time': 1754335777250,
#    'updated': 1754335980218,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252856',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252856&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'ci',
#    'code': '41252856',
#    'ids': ',ci41252856,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 23,
#    'dmin': 0.05029,
#    'rms': 0.22,
#    'gap': 40,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 6 km SSE of Lake Henshaw, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.7305, 33.1915, 11.9]},
#   'id': 'ci41252856'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '40 km NW of Ninilchik, Alaska',
#    'time': 1754335271081,
#    'updated': 1754335405897,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xjiq1w',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xjiq1w&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0259xjiq1w',
#    'ids': ',ak0259xjiq1w,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.65,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 40 km NW of Ninilchik, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.1626, 60.3216, 92.8]},
#   'id': 'ak0259xjiq1w'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.4,
#    'place': '75 km ENE of Lime Village, Alaska',
#    'time': 1754335125372,
#    'updated': 1754335266652,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xji476',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xji476&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 30,
#    'net': 'ak',
#    'code': '0259xji476',
#    'ids': ',ak0259xji476,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.81,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.4 - 75 km ENE of Lime Village, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-154.129, 61.6127, 7.9]},
#   'id': 'ak0259xji476'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.25,
#    'place': '8 km WNW of Cobb, CA',
#    'time': 1754335026080,
#    'updated': 1754337514378,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219137',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219137&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '75219137',
#    'ids': ',nc75219137,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.0135,
#    'rms': 0.02,
#    'gap': 65,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 8 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.817333333333, 38.8356666666667, 2.07]},
#   'id': 'nc75219137'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '74 km NNW of Lake Minchumina, Alaska',
#    'time': 1754334470986,
#    'updated': 1754334581761,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xjft3u',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xjft3u&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '0259xjft3u',
#    'ids': ',ak0259xjft3u,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.55,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 74 km NNW of Lake Minchumina, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.8006, 64.5161, 9]},
#   'id': 'ak0259xjft3u'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.23,
#    'place': '9 km ENE of Running Springs, CA',
#    'time': 1754334059220,
#    'updated': 1754334300761,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252840',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252840&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 23,
#    'net': 'ci',
#    'code': '41252840',
#    'ids': ',ci41252840,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 44,
#    'dmin': 0.01856,
#    'rms': 0.23,
#    'gap': 27,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 9 km ENE of Running Springs, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.0268333, 34.2513333, 0.58]},
#   'id': 'ci41252840'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.57,
#    'place': '3 km S of Fort Hill, Oregon',
#    'time': 1754334012110,
#    'updated': 1754335264970,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62165776',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62165776&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 38,
#    'net': 'uw',
#    'code': '62165776',
#    'ids': ',uw62165776,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 11,
#    'dmin': 0.0973,
#    'rms': 0.2,
#    'gap': 113,
#    'magType': 'ml',
#    'type': 'explosion',
#    'title': 'M 1.6 Explosion - 3 km S of Fort Hill, Oregon'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-123.555, 45.026666666666664, -0.51]},
#   'id': 'uw62165776'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.7,
#    'place': '169 km SE of Petropavlovsk-Kamchatsky, Russia',
#    'time': 1754333554756,
#    'updated': 1754337949040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy30',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy30&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 340,
#    'net': 'us',
#    'code': '6000qy30',
#    'ids': ',us6000qy30,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 32,
#    'dmin': 1.49,
#    'rms': 0.76,
#    'gap': 173,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.7 - 169 km SE of Petropavlovsk-Kamchatsky, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [160.5605, 52.0981, 31.441]},
#   'id': 'us6000qy30'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.7,
#    'place': '147 km SE of Petropavlovsk-Kamchatsky, Russia',
#    'time': 1754333355336,
#    'updated': 1754338313040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy2z',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy2z&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 340,
#    'net': 'us',
#    'code': '6000qy2z',
#    'ids': ',us6000qy2z,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 26,
#    'dmin': 1.287,
#    'rms': 0.75,
#    'gap': 187,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.7 - 147 km SE of Petropavlovsk-Kamchatsky, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [160.2499, 52.1856, 24.891]},
#   'id': 'us6000qy2z'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.28,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1754333278650,
#    'updated': 1754333375140,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219132',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219132&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 1,
#    'net': 'nc',
#    'code': '75219132',
#    'ids': ',nc75219132,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.009886,
#    'rms': 0.01,
#    'gap': 67,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.3 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.818664550781, 38.8306655883789, 1.91999995708466]},
#   'id': 'nc75219132'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.04,
#    'place': '23 km WSW of Klamath Falls, Oregon',
#    'time': 1754333212820,
#    'updated': 1754333962670,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62165756',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62165756&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 17,
#    'net': 'uw',
#    'code': '62165756',
#    'ids': ',uw62165756,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.1096,
#    'rms': 0.19,
#    'gap': 99,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 23 km WSW of Klamath Falls, Oregon'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.05233333333334, 42.17016666666667, 12.64]},
#   'id': 'uw62165756'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.8,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1754333157890,
#    'updated': 1754333255186,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219127',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219127&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'nc',
#    'code': '75219127',
#    'ids': ',nc75219127,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.01146,
#    'rms': 0,
#    'gap': 79,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.82266998291, 38.8330001831055, 2.59999990463257]},
#   'id': 'nc75219127'},
#  {'type': 'Feature',
#   'properties': {'mag': 2.53,
#    'place': '8 km NNW of The Geysers, CA',
#    'time': 1754333077680,
#    'updated': 1754338038256,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75219122',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75219122&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 98,
#    'net': 'nc',
#    'code': '75219122',
#    'ids': ',nc75219122,',
#    'sources': ',nc,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 90,
#    'dmin': 0.009372,
#    'rms': 0.06,
#    'gap': 20,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 2.5 - 8 km NNW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.819, 38.8296666666667, 1.99]},
#   'id': 'nc75219122'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.3,
#    'place': '18 km NW of Tatitlek, Alaska',
#    'time': 1754332073832,
#    'updated': 1754332217424,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xiyo1j',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xiyo1j&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 26,
#    'net': 'ak',
#    'code': '0259xiyo1j',
#    'ids': ',ak0259xiyo1j,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 1.25,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 18 km NW of Tatitlek, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-146.9171, 60.9773, 23.1]},
#   'id': 'ak0259xiyo1j'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.4,
#    'place': '115 km SE of Petropavlovsk-Kamchatsky, Russia',
#    'time': 1754332056663,
#    'updated': 1754339484040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qy2w',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qy2w&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 298,
#    'net': 'us',
#    'code': '6000qy2w',
#    'ids': ',us6000qy2w,',
#    'sources': ',us,',
#    'types': ',origin,phase-data,',
#    'nst': 31,
#    'dmin': 0.998,
#    'rms': 0.75,
#    'gap': 167,
#    'magType': 'mb',
#    'type': 'earthquake',
#    'title': 'M 4.4 - 115 km SE of Petropavlovsk-Kamchatsky, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [159.8217, 52.3269, 36.098]},
#   'id': 'us6000qy2w'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.5,
#    'place': '16 km ESE of Julian, CA',
#    'time': 1754331514210,
#    'updated': 1754332166480,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252832',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252832&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 35,
#    'net': 'ci',
#    'code': '41252832',
#    'ids': ',ci41252832,',
#    'sources': ',ci,',
#    'types': ',focal-mechanism,nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 57,
#    'dmin': 0.04642,
#    'rms': 0.18,
#    'gap': 39,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 16 km ESE of Julian, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-116.4533333, 33.0013333, 9.22]},
#   'id': 'ci41252832'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.9,
#    'place': '78 km WNW of Tyonek, Alaska',
#    'time': 1754331041158,
#    'updated': 1754331146003,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259xiuyec',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259xiuyec&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 56,
#    'net': 'ak',
#    'code': '0259xiuyec',
#    'ids': ',ak0259xiuyec,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.42,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.9 - 78 km WNW of Tyonek, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-152.5165, 61.295, 0.5]},
#   'id': 'ak0259xiuyec'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.08,
#    'place': '15 km NW of Ocotillo, CA',
#    'time': 1754330188850,
#    'updated': 1754368052686,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252816',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252816&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 18,
#    'net': 'ci',
#    'code': '41252816',
#    'ids': ',ci41252816,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 30,
#    'dmin': 0.05421,
#    'rms': 0.16,
#    'gap': 38,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.1 - 15 km NW of Ocotillo, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.082, 32.8446667, 11.97]},
#   'id': 'ci41252816'},
#  {'type': 'Feature',
#   'properties': {'mag': 4.9,
#    'place': '144 km SSE of Vilyuchinsk, Russia',
#    'time': 1754329776959,
#    'updated': 1754331579040,
# ...
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 22,
#    'dmin': 0.006302,
#    'rms': 0.03,
#    'gap': 142,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 13 km NW of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.875333333333, 38.8435, 2.65]},
#   'id': 'nc75218792'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.6,
#    'place': '58 km ESE of Egegik, Alaska',
#    'time': 1754269433988,
#    'updated': 1754269613151,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259x8p5l2',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259x8p5l2&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 39,
#    'net': 'ak',
#    'code': '0259x8p5l2',
#    'ids': ',ak0259x8p5l2,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.68,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 58 km ESE of Egegik, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-156.4461, 58.0239, 140.3]},
#   'id': 'ak0259x8p5l2'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.26,
#    'place': '17 km SW of Nile, Washington',
#    'time': 1754269133200,
#    'updated': 1754281101300,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62165436',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62165436&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 24,
#    'net': 'uw',
#    'code': '62165436',
#    'ids': ',uw62165436,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 22,
#    'dmin': 0.208,
#    'rms': 0.16,
#    'gap': 105,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.3 - 17 km SW of Nile, Washington'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-121.12683333333334, 46.7225, 8.81]},
#   'id': 'uw62165436'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.39,
#    'place': '20 km ESE of Little Lake, CA',
#    'time': 1754269043010,
#    'updated': 1754319321180,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252352',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252352&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 2,
#    'net': 'ci',
#    'code': '41252352',
#    'ids': ',ci41252352,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 11,
#    'dmin': 0.07089,
#    'rms': 0.07,
#    'gap': 89,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 20 km ESE of Little Lake, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-117.6925, 35.8856667, 8.08]},
#   'id': 'ci41252352'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.41,
#    'place': '2 km NNE of The Geysers, CA',
#    'time': 1754268692690,
#    'updated': 1754268787255,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75218782',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75218782&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 3,
#    'net': 'nc',
#    'code': '75218782',
#    'ids': ',nc75218782,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.008674,
#    'rms': 0.07,
#    'gap': 166,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.4 - 2 km NNE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.74983215332, 38.7966651916504, 4.38000011444092]},
#   'id': 'nc75218782'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.79,
#    'place': '2 km NNE of The Geysers, CA',
#    'time': 1754268623470,
#    'updated': 1754268717391,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75218777',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75218777&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 10,
#    'net': 'nc',
#    'code': '75218777',
#    'ids': ',nc75218777,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 9,
#    'dmin': 0.008268,
#    'rms': 0.03,
#    'gap': 175,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 2 km NNE of The Geysers, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.749336242676, 38.798999786377, 1.6599999666214]},
#   'id': 'nc75218777'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.63,
#    'place': '5 km NW of Boron, CA',
#    'time': 1754268549610,
#    'updated': 1754268776152,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252344',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252344&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 41,
#    'net': 'ci',
#    'code': '41252344',
#    'ids': ',ci41252344,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 52,
#    'dmin': 0.09804,
#    'rms': 0.18,
#    'gap': 42,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.6 - 5 km NW of Boron, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-117.6843333, 35.0321667, -0.17]},
#   'id': 'ci41252344'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.46,
#    'place': '4 km NNW of Fern Prairie, Washington',
#    'time': 1754268399010,
#    'updated': 1754283326220,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/uw62165421',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=uw62165421&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 33,
#    'net': 'uw',
#    'code': '62165421',
#    'ids': ',uw62165421,',
#    'sources': ',uw,',
#    'types': ',origin,phase-data,',
#    'nst': 16,
#    'dmin': 0.09751,
#    'rms': 0.14,
#    'gap': 153,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.5 - 4 km NNW of Fern Prairie, Washington'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.424, 45.67133333333334, 13.41]},
#   'id': 'uw62165421'},
#  {'type': 'Feature',
#   'properties': {'mag': 5.2,
#    'place': '123 km S of Vilyuchinsk, Russia',
#    'time': 1754268264717,
#    'updated': 1754355023040,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/us6000qxz1',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=us6000qxz1&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 416,
#    'net': 'us',
#    'code': '6000qxz1',
#    'ids': ',usauto6000qxz1,us6000qxz1,',
#    'sources': ',usauto,us,',
#    'types': ',internal-moment-tensor,origin,phase-data,',
#    'nst': 99,
#    'dmin': 1.207,
#    'rms': 0.63,
#    'gap': 91,
#    'magType': 'mww',
#    'type': 'earthquake',
#    'title': 'M 5.2 - 123 km S of Vilyuchinsk, Russia'},
#   'geometry': {'type': 'Point', 'coordinates': [158.4618, 51.8238, 70]},
#   'id': 'us6000qxz1'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.91,
#    'place': '1 km W of Borrego Springs, CA',
#    'time': 1754268250860,
#    'updated': 1754313644069,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252336',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252336&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 13,
#    'net': 'ci',
#    'code': '41252336',
#    'ids': ',ci41252336,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 53,
#    'dmin': 0.0295,
#    'rms': 0.22,
#    'gap': 43,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.9 - 1 km W of Borrego Springs, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.385, 33.2561667, 2.78]},
#   'id': 'ci41252336'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.62,
#    'place': '46 km SSW of Unalaska, Alaska',
#    'time': 1754268087140,
#    'updated': 1754337847050,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av93047764',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93047764&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 6,
#    'net': 'av',
#    'code': '93047764',
#    'ids': ',av93047764,',
#    'sources': ',av,',
#    'types': ',origin,phase-data,',
#    'nst': 7,
#    'dmin': 0.281,
#    'rms': 0.28,
#    'gap': 313,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.6 - 46 km SSW of Unalaska, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-166.896666666667, 53.5131666666667, 4.39]},
#   'id': 'av93047764'},
#  {'type': 'Feature',
#   'properties': {'mag': 1.2,
#    'place': '61 km E of Port Alsworth, Alaska',
#    'time': 1754268075790,
#    'updated': 1754268202073,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ak0259x8bs8r',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ak0259x8bs8r&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 22,
#    'net': 'ak',
#    'code': '0259x8bs8r',
#    'ids': ',ak0259x8bs8r,',
#    'sources': ',ak,',
#    'types': ',origin,phase-data,',
#    'nst': None,
#    'dmin': None,
#    'rms': 0.54,
#    'gap': None,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 1.2 - 61 km E of Port Alsworth, Alaska'},
#   'geometry': {'type': 'Point', 'coordinates': [-153.2019, 60.1952, 141.1]},
#   'id': 'ak0259x8bs8r'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.84,
#    'place': '0 km N of Borrego Springs, CA',
#    'time': 1754267652120,
#    'updated': 1754327210045,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/ci41252328',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=ci41252328&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 11,
#    'net': 'ci',
#    'code': '41252328',
#    'ids': ',ci41252328,',
#    'sources': ',ci,',
#    'types': ',nearby-cities,origin,phase-data,scitech-link,',
#    'nst': 27,
#    'dmin': 0.03653,
#    'rms': 0.2,
#    'gap': 48,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 0 km N of Borrego Springs, CA'},
#   'geometry': {'type': 'Point', 'coordinates': [-116.3746667, 33.26, 2.93]},
#   'id': 'ci41252328'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.66,
#    'place': '7 km WNW of Cobb, CA',
#    'time': 1754267410690,
#    'updated': 1754267508305,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75218767',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75218767&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 7,
#    'net': 'nc',
#    'code': '75218767',
#    'ids': ',nc75218767,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.005463,
#    'rms': 0.01,
#    'gap': 124,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.7 - 7 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.797332763672, 38.8381652832031, 2.24000000953674]},
#   'id': 'nc75218767'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.96,
#    'place': '7 km WNW of Cobb, CA',
#    'time': 1754267191410,
#    'updated': 1754267288112,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75218762',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75218762&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 14,
#    'net': 'nc',
#    'code': '75218762',
#    'ids': ',nc75218762,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 12,
#    'dmin': 0.007449,
#    'rms': 0.01,
#    'gap': 68,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 1.0 - 7 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.799835205078, 38.8376655578613, 1.80999994277954]},
#   'id': 'nc75218762'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.78,
#    'place': '7 km WNW of Cobb, CA',
#    'time': 1754267139490,
#    'updated': 1754267238129,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75218757',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75218757&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'automatic',
#    'tsunami': 0,
#    'sig': 9,
#    'net': 'nc',
#    'code': '75218757',
#    'ids': ',nc75218757,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 12,
#    'dmin': 0.006804,
#    'rms': 0.02,
#    'gap': 70,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.8 - 7 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.799003601074, 38.8376655578613, 2.25]},
#   'id': 'nc75218757'},
#  {'type': 'Feature',
#   'properties': {'mag': 0.53,
#    'place': '6 km WNW of Cobb, CA',
#    'time': 1754266216590,
#    'updated': 1754333619843,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/nc75218752',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=nc75218752&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 4,
#    'net': 'nc',
#    'code': '75218752',
#    'ids': ',nc75218752,',
#    'sources': ',nc,',
#    'types': ',nearby-cities,origin,phase-data,',
#    'nst': 28,
#    'dmin': 0.002463,
#    'rms': 0.02,
#    'gap': 68,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 0.5 - 6 km WNW of Cobb, CA'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-122.789666666667, 38.836, 2.45]},
#   'id': 'nc75218752'},
#  {'type': 'Feature',
#   'properties': {'mag': 3.18,
#    'place': '79 km N of Cruz Bay, U.S. Virgin Islands',
#    'time': 1754266096550,
#    'updated': 1754267090290,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/pr71491498',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=pr71491498&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 156,
#    'net': 'pr',
#    'code': '71491498',
#    'ids': ',pr71491498,',
#    'sources': ',pr,',
#    'types': ',origin,phase-data,',
#    'nst': 8,
#    'dmin': 0.6159,
#    'rms': 0.44,
#    'gap': 285,
#    'magType': 'md',
#    'type': 'earthquake',
#    'title': 'M 3.2 - 79 km N of Cruz Bay, U.S. Virgin Islands'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-64.6728333333333, 19.0373333333333, 5.04]},
#   'id': 'pr71491498'},
#  {'type': 'Feature',
#   'properties': {'mag': -0.04,
#    'place': '98 km WNW of Aleneva, Alaska',
#    'time': 1754265932890,
#    'updated': 1754337590730,
#    'tz': None,
#    'url': 'https://earthquake.usgs.gov/earthquakes/eventpage/av93701088',
#    'detail': 'https://earthquake.usgs.gov/fdsnws/event/1/query?eventid=av93701088&format=geojson',
#    'felt': None,
#    'cdi': None,
#    'mmi': None,
#    'alert': None,
#    'status': 'reviewed',
#    'tsunami': 0,
#    'sig': 0,
#    'net': 'av',
#    'code': '93701088',
#    'ids': ',av93701088,',
#    'sources': ',av,',
#    'types': ',origin,phase-data,',
#    'nst': 6,
#    'dmin': 0.08549,
#    'rms': 0.12,
#    'gap': 234,
#    'magType': 'ml',
#    'type': 'earthquake',
#    'title': 'M 0.0 - 98 km WNW of Aleneva, Alaska'},
#   'geometry': {'type': 'Point',
#    'coordinates': [-154.388333333333, 58.474, 0.66]},
#   'id': 'av93701088'}]

# %%
# Define your variables
output_data = {
    "start_date": start_date,
    "end_date": end_date,
    "bronze_adls": bronze_adls,
    "silver_adls": silver_adls,
    "gold_adls": gold_adls
}

# Serialize the dictionary to a JSON string
output_json = json.dumps(output_data)

# Log the serialized JSON for debugging
print(f"Serialized JSON: {output_json}")

# Return the JSON string
dbutils.notebook.exit(output_json)
